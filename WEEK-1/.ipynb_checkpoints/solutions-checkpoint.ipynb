# %% [markdown]
# # Objective:-

# %% [markdown]
# Learn Python basics and perform basic data exploration and cleaning using Pandas. Steps:
#
# 1.Load a CSV dataset into a Pandas DataFrame.
#
# 2.Explore data (head/tail, shape, columns, data types).
#
# 3.Handle missing values (identify, fill/drop).
#
# 4.Perform basic operations (filter rows, select columns).
#
# 5.Remove duplicates.
#
# 6.Create a derived column (total_amount = price * quantity).
#
# 7.Save the cleaned dataset as a new CSV file.
#
# Output: Jupyter Notebook (.ipynb) + cleaned CSV + brief summary.

# %% [markdown]
# ### 1.Loading the necessary Python Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2.Loading the CSV dataset into Pandas DataFrame

# %%
ecommerce_data = pd.read_csv("e-commerce1_dataset.csv")
ecommerce_data
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# 995  Men FORTE Silver Automatic Skeleton Analogue W...     3.5             11
# 996  Women White Patterned Dial & White Straps Anal...     5.0             22
# 997  Women Rose Gold-Toned Mirrored Analogue Watch ...     2.8              5
# 998  Men Black Brass Dial & Black Stainless Steel S...     4.3             17
# 999                           Purple Textured Yoga Mat     3.8            161
#
#      initial_price  discount   final_price currency  \
# 0             3995      58.0   "₹3,995.00"      INR
# 1             2899      35.0   "₹2,899.00"      INR
# 2             2999      65.0   "₹2,999.00"      INR
# 3             1675      52.0   "₹1,675.00"      INR
# 4             2899      17.0   "₹2,899.00"      INR
# ..             ...       ...           ...      ...
# 995          11890      50.0  "₹11,890.00"      INR
# 996           8900      45.0   "₹8,900.00"      INR
# 997           7950      50.0   "₹7,950.00"      INR
# 998           3295      20.0   "₹2,636.00"      INR
# 999            699      31.0     "₹699.00"      INR
#
#                                                 images  ...  \
# 0    http://assets.myntassets.com/assets/images/837...  ...
# 1    http://assets.myntassets.com/assets/images/913...  ...
# 2    http://assets.myntassets.com/assets/images/176...  ...
# 3    http://assets.myntassets.com/assets/images/137...  ...
# 4    http://assets.myntassets.com/assets/images/pro...  ...
# ..                                                 ...  ...
# 995  http://assets.myntassets.com/assets/images/136...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
# 997  http://assets.myntassets.com/assets/images/170...  ...
# 998  http://assets.myntassets.com/assets/images/192...  ...
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#                                        amount_of_stars what_customers_said  \
# 0    {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1    {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2    {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
# 3    {"1_star":33,"2_stars":21,"3_stars":69,"4_star...                 NaN
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
# ..                                                 ...                 ...
# 995  {"1_star":3,"2_stars":0,"3_stars":2,"4_stars":...                 NaN
# 996  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
# 997  {"1_star":2,"2_stars":1,"3_stars":0,"4_stars":...                 NaN
# 998  {"1_star":1,"2_stars":2,"3_stars":0,"4_stars":...                 NaN
# 999  {"1_star":24,"2_stars":8,"3_stars":22,"4_stars...                 NaN
#
#         seller_name                                              sizes  \
# 0               NaN                               [{"size":"Onesize"}]
# 1               NaN                               [{"size":"Onesize"}]
# 2               NaN                                     [{"size":"S"}]
# 3               NaN                               [{"size":"Onesize"}]
# 4               NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
# ..              ...                                                ...
# 995             NaN                               [{"size":"Onesize"}]
# 996             NaN                               [{"size":"Onesize"}]
# 997             NaN                               [{"size":"Onesize"}]
# 998  Tru███m R███il                               [{"size":"Onesize"}]
# 999             NaN                                [{"size":"Medium"}]
#
#                                                 videos  \
# 0                                ["rw-8376765_cae700"]
# 1                                ["rw-9136281_cae700"]
# 2    ["https://videos.myntassets.com/assets/videos/...
# 3    ["https://videos.myntassets.com/assets/videos/...
# 4                                                  NaN
# ..                                                 ...
# 995                                    ["pi-13698258"]
# 996  ["rw-16896006_cae700","https://videos.myntasse...
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                     seller_information  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998  Sho███o. ███-10█████████enu███████████████████...
# 999                                                NaN
#
#                                       variations  \
# 0                                           [{}]
# 1                                        [{},{}]
# 2                            [{},{},{},{},{},{}]
# 3                                            NaN
# 4    [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]
# ..                                           ...
# 995                                          NaN
# 996                                          NaN
# 997                    [{},{},{},{},{},{},{},{}]
# 998                                          NaN
# 999                                [{},{},{},{}]
#
#                                             best_offer  \
# 0                                                   {}
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers   category
# 0    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3    [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4    [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
# ..                                                 ...        ...
# 995  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 996  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 997  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 998  [{"offer_name":"10% Instant Discount on IndusI...    watches
# 999  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats
#
# [1000 rows x 24 columns]

# %% [markdown]
# ### 3.Explore data (head/tail, shape, columns, data types)

# %%
ecommerce_data.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# 2  http://assets.myntassets.com/assets/images/176...  ...
# 3  http://assets.myntassets.com/assets/images/137...  ...
# 4  http://assets.myntassets.com/assets/images/pro...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
# 3  {"1_star":33,"2_stars":21,"3_stars":69,"4_star...                 NaN
# 4  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
#
#   seller_name                                              sizes  \
# 0         NaN                               [{"size":"Onesize"}]
# 1         NaN                               [{"size":"Onesize"}]
# 2         NaN                                     [{"size":"S"}]
# 3         NaN                               [{"size":"Onesize"}]
# 4         NaN  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
# 3  ["https://videos.myntassets.com/assets/videos/...                NaN
# 4                                                NaN                NaN
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                          NaN         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
#
# [5 rows x 24 columns]

# %% [markdown]
# The number of visible rows can be changed by passing any desired value in place of `x` in `head(x)`. For example, `head(10)` displays the first 10 rows of the dataset.

# %%
ecommerce_data.head(2)
# Out:
#    product_id           title                product_description  rating  \
# 0     8376765     Lino Perros     Women Navy Blue Solid Backpack     3.8
# 1     9136281  Tommy Hilfiger  Unisex Navy Blue Striped Backpack     4.5
#
#    ratings_count  initial_price  discount  final_price currency  \
# 0             15           3995      58.0  "₹3,995.00"      INR
# 1             67           2899      35.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
#
#   seller_name                 sizes                 videos seller_information  \
# 0         NaN  [{"size":"Onesize"}]  ["rw-8376765_cae700"]                NaN
# 1         NaN  [{"size":"Onesize"}]  ["rw-9136281_cae700"]                NaN
#
#   variations best_offer                                        more_offers  \
# 0       [{}]         {}  [{"offer_name":"10% Instant Discount on Citi C...
# 1    [{},{}]         {}  [{"offer_name":"10% Instant Discount on Citi C...
#
#     category
# 0  backpacks
# 1  backpacks
#
# [2 rows x 24 columns]

# %%
ecommerce_data.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
#                                                 images  ...  \
# 995  http://assets.myntassets.com/assets/images/136...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
# 997  http://assets.myntassets.com/assets/images/170...  ...
# 998  http://assets.myntassets.com/assets/images/192...  ...
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#                                        amount_of_stars what_customers_said  \
# 995  {"1_star":3,"2_stars":0,"3_stars":2,"4_stars":...                 NaN
# 996  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...                 NaN
# 997  {"1_star":2,"2_stars":1,"3_stars":0,"4_stars":...                 NaN
# 998  {"1_star":1,"2_stars":2,"3_stars":0,"4_stars":...                 NaN
# 999  {"1_star":24,"2_stars":8,"3_stars":22,"4_stars...                 NaN
#
#         seller_name                 sizes  \
# 995             NaN  [{"size":"Onesize"}]
# 996             NaN  [{"size":"Onesize"}]
# 997             NaN  [{"size":"Onesize"}]
# 998  Tru███m R███il  [{"size":"Onesize"}]
# 999             NaN   [{"size":"Medium"}]
#
#                                                 videos  \
# 995                                    ["pi-13698258"]
# 996  ["rw-16896006_cae700","https://videos.myntasse...
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                     seller_information  \
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998  Sho███o. ███-10█████████enu███████████████████...
# 999                                                NaN
#
#                     variations  \
# 995                        NaN
# 996                        NaN
# 997  [{},{},{},{},{},{},{},{}]
# 998                        NaN
# 999              [{},{},{},{}]
#
#                                             best_offer  \
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers   category
# 995  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 996  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 997  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 998  [{"offer_name":"10% Instant Discount on IndusI...    watches
# 999  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats
#
# [5 rows x 24 columns]

# %%
ecommerce_data.tail(2)
# Out:
#      product_id     title                                product_description  \
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount  final_price currency  \
# 998     4.3             17           3295      20.0  "₹2,636.00"      INR
# 999     3.8            161            699      31.0    "₹699.00"      INR
#
#                                                 images  ...  \
# 998  http://assets.myntassets.com/assets/images/192...  ...
# 999  http://assets.myntassets.com/assets/images/186...  ...
#
#                                        amount_of_stars what_customers_said  \
# 998  {"1_star":1,"2_stars":2,"3_stars":0,"4_stars":...                 NaN
# 999  {"1_star":24,"2_stars":8,"3_stars":22,"4_stars...                 NaN
#
#         seller_name                 sizes videos  \
# 998  Tru███m R███il  [{"size":"Onesize"}]    NaN
# 999             NaN   [{"size":"Medium"}]    NaN
#
#                                     seller_information     variations  \
# 998  Sho███o. ███-10█████████enu███████████████████...            NaN
# 999                                                NaN  [{},{},{},{}]
#
#                                             best_offer  \
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers   category
# 998  [{"offer_name":"10% Instant Discount on IndusI...    watches
# 999  [{"offer_name":"10% Instant Discount on Citi C...  yoga-mats
#
# [2 rows x 24 columns]

# %%
ecommerce_data.shape
# Out:
# (1000, 24)

# %%
ecommerce_data.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
list(ecommerce_data.columns)
# Out:
# ['product_id',
#  'title',
#  'product_description',
#  'rating',
#  'ratings_count',
#  'initial_price',
#  'discount',
#  'final_price',
#  'currency',
#  'images',
#  'delivery_options',
#  'product_details',
#  'breadcrumbs',
#  'product_specifications',
#  'amount_of_stars',
#  'what_customers_said',
#  'seller_name',
#  'sizes',
#  'videos',
#  'seller_information',
#  'variations',
#  'best_offer',
#  'more_offers',
#  'category']

# %%
ecommerce_data.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %% [markdown]
# The data type of each column can be found separately using the appropriate function or attribute

# %%
ecommerce_data['rating'].dtypes
# Out:
# dtype('float64')

# %%
ecommerce_data['product_id'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### 4. Handle missing values (identify, fill/drop)

# %%
ecommerce_data.head(3)
# Out:
#    product_id           title                product_description  rating  \
# 0     8376765     Lino Perros     Women Navy Blue Solid Backpack     3.8
# 1     9136281  Tommy Hilfiger  Unisex Navy Blue Striped Backpack     4.5
# 2    17633752           Lavie     Aries Women Pink Mini Backpack     4.4
#
#    ratings_count  initial_price  discount  final_price currency  \
# 0             15           3995      58.0  "₹3,995.00"      INR
# 1             67           2899      35.0  "₹2,899.00"      INR
# 2            226           2999      65.0  "₹2,999.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# 2  http://assets.myntassets.com/assets/images/176...  ...
#
#                                      amount_of_stars what_customers_said  \
# 0  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...                 NaN
# 1  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...                 NaN
# 2  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...                 NaN
#
#   seller_name                 sizes  \
# 0         NaN  [{"size":"Onesize"}]
# 1         NaN  [{"size":"Onesize"}]
# 2         NaN        [{"size":"S"}]
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                NaN
# 1                              ["rw-9136281_cae700"]                NaN
# 2  ["https://videos.myntassets.com/assets/videos/...                NaN
#
#             variations best_offer  \
# 0                 [{}]         {}
# 1              [{},{}]         {}
# 2  [{},{},{},{},{},{}]         {}
#
#                                          more_offers   category
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks
#
# [3 rows x 24 columns]

# %%
ecommerce_data.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
ecommerce_data[['discount','what_customers_said','videos','seller_information','variations']].sample(3)
# Out:
#      discount                                what_customers_said  \
# 393      70.0  [{"percentage":"100","value_name":"Fit, Just R...
# 349      58.0  [{"percentage":"52","value_name":"Fit, Just Ri...
# 854       NaN                                                NaN
#
#                                                 videos  \
# 393                                                NaN
# 349                                                NaN
# 854  ["https://videos.myntassets.com/assets/videos/...
#
#                                     seller_information              variations
# 393                                                NaN                     NaN
# 349  Fir███Flo███ 27█████████ Ku███████████████████...  [{},{},{},{},{},{},{}]
# 854                                                NaN              [{},{},{}]

# %% [markdown]
# Instead of assigning the result back to the column using `ecommerce_data['what_customers_said'] = ecommerce_data['what_customers_said'].fillna('No reviews')`, `fillna('No reviews', inplace=True)` can also be used. With `inplace=True`, the changes are applied directly to the original dataset without needing reassignment."

# %%
ecommerce_data['discount'] = ecommerce_data['discount'].fillna(0)

# %%
ecommerce_data['what_customers_said'] = ecommerce_data['what_customers_said'].fillna('No reviews')

# %%
ecommerce_data['seller_name'] = ecommerce_data['seller_name'].fillna('Unknown Seller')

# %%
ecommerce_data['videos'] = ecommerce_data['videos'].fillna('Unknown')

# %%
ecommerce_data['seller_information'] = ecommerce_data['seller_information'].fillna('[]')

# %%
ecommerce_data['variations'] = ecommerce_data['variations'].fillna('[]')

# %%
ecommerce_data.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %% [markdown]
# ### 5.Perform basic operations (filter rows, select columns)

# %%
ecommerce_data[ecommerce_data['discount']>=80]
# Out:
#      product_id                                       title  \
# 18     22409156                                     Kastner
# 21      1728397                                     Mactree
# 47     19206416                                     ABELINO
# 102    21988674                                     Sangria
# 114    18951632                                   Berrylush
# 176    13382036                                       plusS
# 213    10125241                                   KARATCART
# 215    20064092                                         AMI
# 227    13401002                         Adwitiya Collection
# 228    13340876                                  Kord Store
# 229    12930940  TOKYO TALKIES X rubans FASHION ACCESSORIES
# 236    22593680                                      ZENEME
# 356    19837040                                   High Star
# 357    19837008                                   High Star
# 447    12509548                                       Ishin
# 455    19027344                                     Jompers
# 491    17359602                                Swiss Design
# 507    15294314                               Zaveri Pearls
# 508    16254760                               Zaveri Pearls
# 512    15679734                                 John Karsun
# 540    19823504                                    VAIRAGEE
# 628    18690268                                Dennis Lingo
# 681    14480064                                    AfroJack
# 767    17156676                                Thomas Scott
# 769    17157846                                Thomas Scott
# 801    13466462                                 Global Desi
# 842    18972596                                     MALHAAR
# 874    17950198                                     PURVAJA
# 888    17950208                                     PURVAJA
# 896    17950338                                     PURVAJA
# 897    11876926                                         AND
# 920    18688608                                Nasher Miles
# 925    22323008                                Dennis Lingo
# 963    20085320                                     BULLMER
# 965    12987894                   AMERICAN EAGLE OUTFITTERS
# 976    13721540                                  Art Street
# 990     9053317                                   TIMESMITH
#
#                                    product_description  rating  ratings_count  \
# 18                       Women Textured Tang Slim Belt     3.8              9
# 21                  Men Brown Solid Mid-Top Flat Boots     3.9           1727
# 47   Women Set of 3 Assorted Cotton Boy Shorts Brie...     3.6             14
# 102                 Floral Printed Tiered A-Line Dress     0.0              0
# 114              Women White Floral Pattern Play Dress     3.9             69
# 176  Women Olive Green Accordion Pleated Midi A-Lin...     4.2            623
# 213  Green Gold-Plated Beaded Enamelled Floral Chan...     4.2             22
# 215  Set Of 25 Gold-Toned Gold Plated Contemporary ...     3.8              6
# 227             Gold-Toned & Green Dome Shaped Jhumkas     0.0              0
# 228          Red Gold Plated Meenakari Classic Jhumkas     4.4              7
# 229     Gold-Plated & White Contemporary Drop Earrings     3.9             14
# 236           Gold-Plated Dome Shaped Jhumkas Earrings     0.0              0
# 356         Women Olive Green Solid Crop Padded Jacket     4.1             41
# 357                 Women Navy Blue Solid Parka Jacket     3.9             32
# 447  Women Maroon & Off-White Printed A-Line Kurta ...     0.0              0
# 455       Men Maroon Ethnic Motifs Kurta with Churidar     0.0              0
# 491  Pack Of 20 Assorted 5-Ply Anti-Pollution N95 M...     3.0              2
# 507  Set of 2 Rose Gold Plated CZ-Studded Contempor...     4.4             27
# 508  Set Of 3 Gold-Plated White & Green Kundan-Stud...     4.2            504
# 512                          Men Black Comfort Sandals     2.7             10
# 540        Black Embellished Sequinned Celebrity Saree     4.2             19
# 628                 Men Slim Fit Tropical Casual Shirt     4.6              5
# 681  Men Black Textile Long Distance Running Non-Ma...     3.1             46
# 767                  Men Green  Sustainable Sweatshirt     3.6             20
# 769                   Men Blue  Sustainable Sweatshirt     3.5             10
# 801     Pink Geometric Printed Slit Sleeves A-line Top     3.4             11
# 842      White & Brown Print Smocked Cinched Waist Top     0.0              0
# 874  Women Solid Pink Round Neck Leg of Mutton Slee...     3.4             29
# 888                                Pink Solid Crop Top     3.5             20
# 896                      Women Peach-Coloured Crop Top     4.2             16
# 897                             Women Blue Printed Top     4.4             57
# 920               Jaisalmer Textured Large Trolley Bag     3.3              8
# 925                        Men Slim Fit Chino Trousers     3.8              5
# 963  Men Pack of 2 Navy Blue & Turquoise Blue Long ...     4.8             12
# 965    Women White & Yellow Printed Round Neck T-shirt     4.4              5
# 976  Set Of 3 Brown & Green Monuments Theme Framed ...     3.9              8
# 990                   Men Black Analogue Watch TSC-008     3.7            304
#
#      initial_price  discount   final_price currency  \
# 18            1399      84.0     "₹223.00"      INR
# 21            9060      88.0   "₹1,087.00"      INR
# 47            1899      80.0     "₹379.00"      INR
# 102           2999      80.0     "₹599.00"      INR
# 114           1899      80.0     "₹379.00"      INR
# 176           1899      83.0     "₹322.00"      INR
# 213           1711      82.0     "₹307.00"      INR
# 215           1995      80.0     "₹399.00"      INR
# 227           3189      81.0     "₹599.00"      INR
# 228           4524      88.0     "₹542.00"      INR
# 229           1650      81.0     "₹313.00"      INR
# 236           2999      87.0     "₹389.00"      INR
# 356           3749      85.0   "₹3,749.00"      INR
# 357           4549      85.0   "₹4,549.00"      INR
# 447           3899      86.0     "₹545.00"      INR
# 455           3499      80.0     "₹699.00"      INR
# 491           1500      85.0     "₹225.00"      INR
# 507           1995      82.0     "₹359.00"      INR
# 508           2250      81.0   "₹2,250.00"      INR
# 512           3649      81.0     "₹693.00"      INR
# 540           9995      83.0   "₹1,699.00"      INR
# 628           1999      80.0   "₹1,999.00"      INR
# 681           3995      80.0     "₹799.00"      INR
# 767           4799      85.0   "₹4,799.00"      INR
# 769           3999      82.0   "₹3,999.00"      INR
# 801           1599      80.0   "₹1,599.00"      INR
# 842           3329      82.0     "₹599.00"      INR
# 874           2199      81.0   "₹2,199.00"      INR
# 888           2199      81.0   "₹2,199.00"      INR
# 896           2199      81.0   "₹2,199.00"      INR
# 897           1999      80.0   "₹1,999.00"      INR
# 920          17995      85.0  "₹17,995.00"      INR
# 925           3099      82.0     "₹557.00"      INR
# 963           3998      80.0     "₹799.00"      INR
# 965           1799      80.0     "₹359.00"      INR
# 976           3500      84.0     "₹560.00"      INR
# 990           2499      88.0   "₹2,499.00"      INR
#
#                                                 images  ...  \
# 18   http://assets.myntassets.com/assets/images/224...  ...
# 21   http://assets.myntassets.com/assets/images/172...  ...
# 47   http://assets.myntassets.com/assets/images/192...  ...
# 102  http://assets.myntassets.com/assets/images/219...  ...
# 114  http://assets.myntassets.com/assets/images/189...  ...
# 176  http://assets.myntassets.com/assets/images/133...  ...
# 213  http://assets.myntassets.com/assets/images/101...  ...
# 215  http://assets.myntassets.com/assets/images/200...  ...
# 227  http://assets.myntassets.com/assets/images/pro...  ...
# 228  http://assets.myntassets.com/assets/images/133...  ...
# 229  http://assets.myntassets.com/assets/images/129...  ...
# 236  http://assets.myntassets.com/assets/images/225...  ...
# 356  http://assets.myntassets.com/assets/images/198...  ...
# 357  http://assets.myntassets.com/assets/images/198...  ...
# 447  http://assets.myntassets.com/assets/images/125...  ...
# 455  http://assets.myntassets.com/assets/images/190...  ...
# 491  http://assets.myntassets.com/assets/images/173...  ...
# 507  http://assets.myntassets.com/assets/images/152...  ...
# 508  http://assets.myntassets.com/assets/images/162...  ...
# 512  http://assets.myntassets.com/assets/images/156...  ...
# 540  http://assets.myntassets.com/assets/images/198...  ...
# 628  http://assets.myntassets.com/assets/images/186...  ...
# 681  http://assets.myntassets.com/assets/images/pro...  ...
# 767  http://assets.myntassets.com/assets/images/171...  ...
# 769  http://assets.myntassets.com/assets/images/171...  ...
# 801  http://assets.myntassets.com/assets/images/134...  ...
# 842  http://assets.myntassets.com/assets/images/189...  ...
# 874  http://assets.myntassets.com/assets/images/179...  ...
# 888  http://assets.myntassets.com/assets/images/179...  ...
# 896  http://assets.myntassets.com/assets/images/179...  ...
# 897  http://assets.myntassets.com/assets/images/118...  ...
# 920  http://assets.myntassets.com/assets/images/186...  ...
# 925  http://assets.myntassets.com/assets/images/223...  ...
# 963  http://assets.myntassets.com/assets/images/200...  ...
# 965  http://assets.myntassets.com/assets/images/pro...  ...
# 976  http://assets.myntassets.com/assets/images/137...  ...
# 990  http://assets.myntassets.com/assets/images/905...  ...
#
#                                        amount_of_stars  \
# 18   {"1_star":2,"2_stars":0,"3_stars":0,"4_stars":...
# 21   {"1_star":228,"2_stars":89,"3_stars":186,"4_st...
# 47   {"1_star":2,"2_stars":3,"3_stars":1,"4_stars":...
# 102  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 114  {"1_star":13,"2_stars":2,"3_stars":5,"4_stars"...
# 176  {"1_star":47,"2_stars":31,"3_stars":60,"4_star...
# 213  {"1_star":1,"2_stars":3,"3_stars":2,"4_stars":...
# 215  {"1_star":0,"2_stars":1,"3_stars":2,"4_stars":...
# 227  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 228  {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 229  {"1_star":1,"2_stars":3,"3_stars":0,"4_stars":...
# 236  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 356  {"1_star":0,"2_stars":2,"3_stars":7,"4_stars":...
# 357  {"1_star":5,"2_stars":2,"3_stars":2,"4_stars":...
# 447  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 455  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 491  {"1_star":1,"2_stars":0,"3_stars":0,"4_stars":...
# 507  {"1_star":1,"2_stars":0,"3_stars":4,"4_stars":...
# 508  {"1_star":33,"2_stars":26,"3_stars":57,"4_star...
# 512  {"1_star":3,"2_stars":3,"3_stars":1,"4_stars":...
# 540  {"1_star":3,"2_stars":0,"3_stars":1,"4_stars":...
# 628  {"1_star":0,"2_stars":0,"3_stars":1,"4_stars":...
# 681  {"1_star":14,"2_stars":3,"3_stars":6,"4_stars"...
# 767  {"1_star":3,"2_stars":2,"3_stars":3,"4_stars":...
# 769  {"1_star":2,"2_stars":0,"3_stars":2,"4_stars":...
# 801  {"1_star":3,"2_stars":1,"3_stars":1,"4_stars":...
# 842  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 874  {"1_star":7,"2_stars":3,"3_stars":3,"4_stars":...
# 888  {"1_star":3,"2_stars":1,"3_stars":4,"4_stars":...
# 896  {"1_star":0,"2_stars":0,"3_stars":2,"4_stars":...
# 897  {"1_star":7,"2_stars":0,"3_stars":1,"4_stars":...
# 920  {"1_star":3,"2_stars":0,"3_stars":0,"4_stars":...
# 925  {"1_star":0,"2_stars":0,"3_stars":2,"4_stars":...
# 963  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 965  {"1_star":0,"2_stars":0,"3_stars":1,"4_stars":...
# 976  {"1_star":1,"2_stars":1,"3_stars":0,"4_stars":...
# 990  {"1_star":54,"2_stars":20,"3_stars":34,"4_star...
#
#                                    what_customers_said  \
# 18                                          No reviews
# 21                                          No reviews
# 47                                          No reviews
# 102                                         No reviews
# 114  [{"percentage":"100","value_name":"Fit, Just R...
# 176  [{"percentage":"86","value_name":"Fit, Just Ri...
# 213                                         No reviews
# 215                                         No reviews
# 227                                         No reviews
# 228                                         No reviews
# 229                                         No reviews
# 236                                         No reviews
# 356  [{"percentage":"100","value_name":"Fit, Just R...
# 357  [{"percentage":"57","value_name":"Fit, Just Ri...
# 447  [{"percentage":"100","value_name":"Fit, Just R...
# 455                                         No reviews
# 491                                         No reviews
# 507                                         No reviews
# 508                                         No reviews
# 512                                         No reviews
# 540  [{"percentage":"100","value_name":"Fabric Qual...
# 628                                         No reviews
# 681                                         No reviews
# 767  [{"percentage":"100","value_name":"Fit, Just R...
# 769  [{"percentage":"50","value_name":"Fit, A Littl...
# 801  [{"percentage":"100","value_name":"Fit, A Litt...
# 842                                         No reviews
# 874  [{"percentage":"100","value_name":"Fit, Loose"...
# 888  [{"percentage":"100","value_name":"Fit, A Litt...
# 896                                         No reviews
# 897                                         No reviews
# 920                                         No reviews
# 925                                         No reviews
# 963                                         No reviews
# 965                                         No reviews
# 976                                         No reviews
# 990                                         No reviews
#
#                                     seller_name  \
# 18            Kas███r L███her█████████Pvt██████
# 21                        MAX███ IN███NAT██████
# 47                     ARI███T T███ING█████████
# 102                                       SWARR
# 114                                Sup███om ███
# 176              Shi███Int███ati█████████rel███
# 213                    KOK███V G███AL █████████
# 215                               ZAV███ PE███S
# 227           ADW███YA ███HIO█████████ LI██████
# 228                                Kor███yst███
# 229                                Sup███om ███
# 236                                GLO███ NE███
# 356                              Unknown Seller
# 357                              Unknown Seller
# 447  Men███Bra███Tec█████████ Pr███████████████
# 455              IND███ NE███E P█████████MIT███
# 491              HOU███OF ███NDS█████████LLP███
# 507                               ZAV███ PE███S
# 508                              Unknown Seller
# 512                          KAR███ OV███EAS███
# 540                       Viv███ In███nat██████
# 628                              Unknown Seller
# 681                       WIN███INT███ATI██████
# 767                              Unknown Seller
# 769                              Unknown Seller
# 801                              Unknown Seller
# 842                       BED███E S███IES██████
# 874                              Unknown Seller
# 888                              Unknown Seller
# 896                              Unknown Seller
# 897                              Unknown Seller
# 920                              Unknown Seller
# 925  Men███Bra███Tec█████████ Pr███████████████
# 963                    Bod███ove███par█████████
# 965           Wes███ry ███din█████████d_M██████
# 976                                EDG███QUA███
# 990                              Unknown Seller
#
#                                                  sizes  \
# 18   [{"size":"26","value":"26.0in","value_name":"T...
# 21   [{"size":"6","value":"25.1cm","value_name":"To...
# 47   [{"size":"S","value":"26.0in","value_name":"To...
# 102  [{"size":"XS","value":"32.0in","value_name":"T...
# 114  [{"size":"S","value":"33.0in","value_name":"Fr...
# 176  [{"size":"S","value":"36.0in","value_name":"Bu...
# 213                               [{"size":"Onesize"}]
# 215                               [{"size":"Onesize"}]
# 227                               [{"size":"Onesize"}]
# 228                               [{"size":"Onesize"}]
# 229                               [{"size":"Onesize"}]
# 236                               [{"size":"Onesize"}]
# 356  [{"size":"S","value":"38.0in","value_name":"Bu...
# 357  [{"size":"S","value":"38.0in","value_name":"Bu...
# 447  [{"size":"S","value":"36.5in","value_name":"Bu...
# 455  [{"size":"S","value":"41.0in","value_name":"Ch...
# 491                               [{"size":"Onesize"}]
# 507                               [{"size":"Onesize"}]
# 508  [{"size":"Onesize","value":"2.5in","value_name...
# 512  [{"size":"6","value":"25.1cm","value_name":"To...
# 540                               [{"size":"Onesize"}]
# 628  [{"size":"38","value":"39.0in","value_name":"C...
# 681  [{"size":"7","value":"27.0cm","value_name":"To...
# 767  [{"size":"S","value":"39.0in","value_name":"Ch...
# 769  [{"size":"S","value":"39.0in","value_name":"Ch...
# 801  [{"size":"XS","value":"34.0in","value_name":"B...
# 842  [{"size":"XS","value":"33.0in","value_name":"T...
# 874  [{"size":"S","value":"32.0in","value_name":"To...
# 888  [{"size":"S","value":"32.0in","value_name":"To...
# 896  [{"size":"S","value":"32.0in","value_name":"To...
# 897  [{"size":"XS","value":"31.0in","value_name":"T...
# 920  [{"size":"S","value":"55.0cm","value_name":"Ba...
# 925  [{"size":"28","value":"23.0in","value_name":"T...
# 963  [{"size":"M","value":"39.0in","value_name":"Ch...
# 965  [{"size":"XS","value":"29.0in","value_name":"T...
# 976                               [{"size":"Onesize"}]
# 990                               [{"size":"Onesize"}]
#
#                                                 videos  \
# 18                                             Unknown
# 21                                             Unknown
# 47                                             Unknown
# 102                                            Unknown
# 114                                            Unknown
# 176                                            Unknown
# 213                                            Unknown
# 215                                            Unknown
# 227                                            Unknown
# 228                                            Unknown
# 229                                            Unknown
# 236                                            Unknown
# 356                                            Unknown
# 357                                            Unknown
# 447                                            Unknown
# 455                                            Unknown
# 491                                            Unknown
# 507                                            Unknown
# 508  ["rw-16254760_cae700","https://videos.myntasse...
# 512                                            Unknown
# 540                                            Unknown
# 628                                            Unknown
# 681                             ["rw-14480064_cae700"]
# 767                                            Unknown
# 769                                            Unknown
# 801                                            Unknown
# 842                                            Unknown
# 874                                            Unknown
# 888                                            Unknown
# 896                                            Unknown
# 897                             ["rw-11876926_cae700"]
# 920                                            Unknown
# 925                                            Unknown
# 963                                            Unknown
# 965                                            Unknown
# 976                                            Unknown
# 990  ["rw-9053317_cae700","https://videos.myntasset...
#
#                                     seller_information  \
# 18    A-5███ADA███R V█████████ De█████████████████████
# 21   21/███10 ███NS █████████4 ,███████████████████...
# 47   F-2███RST███OOR█████████7VA███████████████████...
# 102  D-2███Sec███ 06█████████uta███████████████████...
# 114  Plo███o- ███ 1s█████████Sui███████████████████...
# 176  Fir███and███con█████████A 3███████████████████...
# 213  Sho███58-███Sec█████████ain███████████████████...
# 215  12,███T F███R, █████████LDG███████████████████...
# 227   D-1███ Vi███ Vi█████████, U█████████████████████
# 228  1st███oor███apa█████████,Na███████████████████...
# 229  Plo███o- ███ 1s█████████Sui███████████████████...
# 236  FIR███FLO███ 50█████████ND ███████████████████...
# 356                                                 []
# 357                                                 []
# 447  2nd███oor███O. █████████Lan███████████████████...
# 455  HOU███NO.███ GR█████████R, ███████████████████...
# 491  3RD███OOR███ AN█████████OCK███████████████████...
# 507  12,███T F███R, █████████LDG███████████████████...
# 508                                                 []
# 512  179███Kav███ Ku█████████2Ka███████████████████...
# 540  201███ew ███dar█████████mar███████████████████...
# 628                                                 []
# 681  PLO███O. ███18,█████████RJE███████████████████...
# 767                                                 []
# 769                                                 []
# 801                                                 []
# 842  1/4███Rii███Ind█████████rea███████████████████...
# 874                                                 []
# 888                                                 []
# 896                                                 []
# 897                                                 []
# 920                                                 []
# 925  2nd███oor███O. █████████Lan███████████████████...
# 963  Bod███ove███par█████████ No███████████████████...
# 965  Gro███ Fl███, N█████████old███████████████████...
# 976  I-6███URA███R I█████████ AR███████████████████...
# 990                                                 []
#
#                           variations  \
# 18               [{},{},{},{},{},{}]
# 21                              [{}]
# 47                           [{},{}]
# 102                    [{},{},{},{}]
# 114                       [{},{},{}]
# 176                             [{}]
# 213                               []
# 215                               []
# 227                             [{}]
# 228                               []
# 229                               []
# 236                 [{},{},{},{},{}]
# 356                          [{},{}]
# 357                          [{},{}]
# 447                               []
# 455                 [{},{},{},{},{}]
# 491                               []
# 507                               []
# 508                               []
# 512                               []
# 540                       [{},{},{}]
# 628                             [{}]
# 681                               []
# 767                    [{},{},{},{}]
# 769        [{},{},{},{},{},{},{},{}]
# 801                               []
# 842                 [{},{},{},{},{}]
# 874                       [{},{},{}]
# 888                               []
# 896                       [{},{},{}]
# 897                               []
# 920                       [{},{},{}]
# 925  [{},{},{},{},{},{},{},{},{},{}]
# 963                               []
# 965                               []
# 976                               []
# 990                               []
#
#                                             best_offer  \
# 18   {"applicable_on":"Orders above Rs. 649 (only o...
# 21   {"applicable_on":"Orders above Rs. 999 (only o...
# 47   {"applicable_on":"Orders above Rs. 649 (only o...
# 102  {"applicable_on":"Orders above Rs. 749 (only o...
# 114  {"applicable_on":"Orders above Rs. 649 (only o...
# 176  {"applicable_on":"Orders above Rs. 649 (only o...
# 213  {"applicable_on":"Orders above Rs. 649 (only o...
# 215  {"applicable_on":"Orders above Rs. 649 (only o...
# 227  {"applicable_on":"Orders above Rs. 649 (only o...
# 228  {"applicable_on":"Orders above Rs. 649 (only o...
# 229  {"applicable_on":"Orders above Rs. 649 (only o...
# 236  {"applicable_on":"Orders above Rs. 649 (only o...
# 356                                                 {}
# 357                                                 {}
# 447  {"applicable_on":"Orders above Rs. 1299 (only ...
# 455  {"applicable_on":"Orders above Rs. 999 (only o...
# 491  {"applicable_on":"Orders above Rs. 649 (only o...
# 507  {"applicable_on":"Orders above Rs. 1299 (only ...
# 508                                                 {}
# 512  {"applicable_on":"Orders above Rs. 999 (only o...
# 540  {"applicable_on":"Orders above Rs. 1499 (only ...
# 628                                                 {}
# 681  {"applicable_on":"Orders above Rs. 999 (only o...
# 767                                                 {}
# 769                                                 {}
# 801                                                 {}
# 842  {"applicable_on":"Orders above Rs. 649 (only o...
# 874                                                 {}
# 888                                                 {}
# 896                                                 {}
# 897                                                 {}
# 920                                                 {}
# 925  {"applicable_on":"Orders above Rs. 649 (only o...
# 963  {"applicable_on":"Orders above Rs. 999 (only o...
# 965  {"applicable_on":"Orders above Rs. 649 (only o...
# 976  {"applicable_on":"Orders above Rs. 649 (only o...
# 990                                                 {}
#
#                                            more_offers       category
# 18   [{"offer_name":"10% Instant Discount on IndusI...          belts
# 21   [{"offer_name":"10% Instant Discount on IndusI...          boots
# 47   [{"offer_name":"10% Instant Discount on IndusI...         briefs
# 102  [{"offer_name":"10% Instant Discount on IndusI...        dresses
# 114  [{"offer_name":"10% Instant Discount on IndusI...        dresses
# 176  [{"offer_name":"10% Instant Discount on IndusI...        dresses
# 213  [{"offer_name":"10% Instant Discount on IndusI...       earrings
# 215  [{"offer_name":"10% Instant Discount on IndusI...       earrings
# 227  [{"offer_name":"10% Instant Discount on IndusI...       earrings
# 228  [{"offer_name":"10% Instant Discount on IndusI...       earrings
# 229  [{"offer_name":"10% Instant Discount on IndusI...       earrings
# 236  [{"offer_name":"10% Instant Discount on IndusI...       earrings
# 356  [{"offer_name":"10% Instant Discount on Citi C...        jackets
# 357  [{"offer_name":"10% Instant Discount on Citi C...        jackets
# 447  [{"offer_name":"10% Instant Discount on Citi C...         kurtas
# 455  [{"offer_name":"10% Instant Discount on IndusI...     kurta-sets
# 491  [{"offer_name":"10% Instant Discount on IndusI...  outdoor-masks
# 507  [{"offer_name":"10% Instant Discount on Citi C...           ring
# 508  [{"offer_name":"10% Instant Discount on Citi C...           ring
# 512  [{"offer_name":"10% Instant Discount on IndusI...        sandals
# 540  [{"offer_name":"10% Instant Discount on IndusI...         sarees
# 628  [{"offer_name":"10% Instant Discount on Citi C...         shirts
# 681  [{"offer_name":"10% Instant Discount on IndusI...   sports-shoes
# 767  [{"offer_name":"10% Instant Discount on Citi C...    sweatshirts
# 769  [{"offer_name":"10% Instant Discount on Citi C...    sweatshirts
# 801  [{"offer_name":"10% Instant Discount on Citi C...           tops
# 842  [{"offer_name":"10% Instant Discount on IndusI...           tops
# 874  [{"offer_name":"10% Instant Discount on Citi C...           tops
# 888  [{"offer_name":"10% Instant Discount on Citi C...           tops
# 896  [{"offer_name":"10% Instant Discount on Citi C...           tops
# 897  [{"offer_name":"10% Instant Discount on Citi C...           tops
# 920  [{"offer_name":"10% Instant Discount on Citi C...    trolley-bag
# 925  [{"offer_name":"10% Instant Discount on IndusI...       trousers
# 963  [{"offer_name":"10% Instant Discount on IndusI...        tshirts
# 965  [{"offer_name":"10% Instant Discount on IndusI...        tshirts
# 976  [{"offer_name":"10% Instant Discount on IndusI...       wall-art
# 990  [{"offer_name":"10% Instant Discount on Citi C...        watches
#
# [37 rows x 24 columns]

# %%
ecommerce_data[ecommerce_data['rating']>=4.6]
# Out:
#      product_id           title  \
# 4      13939916       MYTRIDENT
# 7      18602872         My Room
# 22     21427828      London Rag
# 32     18656766           VStar
# 38     21873792       KARATCART
# ..          ...             ...
# 963    20085320         BULLMER
# 968    19291812  Mad Over Print
# 986    17697474           Timex
# 992    11791782           CASIO
# 996    16896006           GUESS
#
#                                    product_description  rating  ratings_count  \
# 4                             Men Blue Solid Bath Robe     4.7             12
# 7    Yellow & Green Floral 140 TC King Bedsheet wit...     4.7             10
# 22                Women Stiletto Heeled High-Top Boots     5.0              4
# 32                             Beige Solid T-Shirt Bra     4.6              5
# 38    Cubic Zirconia Silver-Plated Wraparound Bracelet     4.6              5
# ..                                                 ...     ...            ...
# 963  Men Pack of 2 Navy Blue & Turquoise Blue Long ...     4.8             12
# 968             Women Black Love Wins Oversize T-shirt     4.8              5
# 986  Women White Dial & Gold Toned Analogue Watch T...     4.9              8
# 992  Youth Digital Women Red Digital Watch I117 DW-...     4.6             29
# 996  Women White Patterned Dial & White Straps Anal...     5.0             22
#
#      initial_price  discount  final_price currency  \
# 4             2899      17.0  "₹2,899.00"      INR
# 7             2999      54.0  "₹2,999.00"      INR
# 22            9599      60.0  "₹3,839.00"      INR
# 32             345       0.0    "₹345.00"      INR
# 38            3397      76.0    "₹815.00"      INR
# ..             ...       ...          ...      ...
# 963           3998      80.0    "₹799.00"      INR
# 968           1599      58.0    "₹671.00"      INR
# 986           1995      20.0  "₹1,596.00"      INR
# 992           3595      10.0  "₹3,235.00"      INR
# 996           8900      45.0  "₹8,900.00"      INR
#
#                                                 images  ...  \
# 4    http://assets.myntassets.com/assets/images/pro...  ...
# 7    http://assets.myntassets.com/assets/images/186...  ...
# 22   http://assets.myntassets.com/assets/images/214...  ...
# 32   http://assets.myntassets.com/assets/images/186...  ...
# 38   http://assets.myntassets.com/assets/images/218...  ...
# ..                                                 ...  ...
# 963  http://assets.myntassets.com/assets/images/200...  ...
# 968  http://assets.myntassets.com/assets/images/192...  ...
# 986  http://assets.myntassets.com/assets/images/176...  ...
# 992  http://assets.myntassets.com/assets/images/117...  ...
# 996  http://assets.myntassets.com/assets/images/168...  ...
#
#                                        amount_of_stars  \
# 4    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 7    {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 22   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 32   {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 38   {"1_star":0,"2_stars":0,"3_stars":1,"4_stars":...
# ..                                                 ...
# 963  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 968  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 986  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
# 992  {"1_star":1,"2_stars":1,"3_stars":0,"4_stars":...
# 996  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...
#
#                                    what_customers_said  \
# 4                                           No reviews
# 7                                           No reviews
# 22                                          No reviews
# 32                                          No reviews
# 38                                          No reviews
# ..                                                 ...
# 963                                         No reviews
# 968  [{"percentage":"100","value_name":"Fit, A Litt...
# 986                                         No reviews
# 992                                         No reviews
# 996                                         No reviews
#
#                                  seller_name  \
# 4                             Unknown Seller
# 7                             Unknown Seller
# 22                  VOL███FAS███N P█████████
# 32                  V S███ CR███ION█████████
# 38                  KOK███V G███AL █████████
# ..                                       ...
# 963                 Bod███ove███par█████████
# 968           MAD███R P███T P█████████MIT███
# 986  TIM███T R███IL █████████RIV████████████
# 992                       Fla███ech███tai███
# 996                           Unknown Seller
#
#                                                  sizes  \
# 4    [{"size":"M","value":"45.0in","value_name":"Fr...
# 7    [{"size":"Single"},{"size":"Double Queen"},{"s...
# 22   [{"size":"3","value":"23.0cm","value_name":"To...
# 32   [{"size":"30B","value":"31.5in","value_name":"...
# 38   [{"size":"Onesize","value":"8.26in","value_nam...
# ..                                                 ...
# 963  [{"size":"M","value":"39.0in","value_name":"Ch...
# 968  [{"size":"S","value":"39.3in","value_name":"Bu...
# 986                               [{"size":"Onesize"}]
# 992                               [{"size":"Onesize"}]
# 996                               [{"size":"Onesize"}]
#
#                                                 videos  \
# 4                                              Unknown
# 7                                              Unknown
# 22                                             Unknown
# 32                                             Unknown
# 38                                             Unknown
# ..                                                 ...
# 963                                            Unknown
# 968                                            Unknown
# 986                                            Unknown
# 992  ["https://videos.myntassets.com/assets/videos/...
# 996  ["rw-16896006_cae700","https://videos.myntasse...
#
#                                     seller_information  \
# 4                                                   []
# 7                                                   []
# 22   SAI███USE███OT █████████ NA███████████████████...
# 32   VI/███ AB███ ST█████████ODE███████████████████...
# 38   Sho███58-███Sec█████████ain███████████████████...
# ..                                                 ...
# 963  Bod███ove███par█████████ No███████████████████...
# 968  621███ 6n███ kh█████████zia███████████████████...
# 986  Fla███o. ███, 6█████████y C███████████████████...
# 992  3rd███165███th █████████, s███████████████████...
# 996                                                 []
#
#                                       variations  \
# 4    [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]
# 7                                           [{}]
# 22                                            []
# 32                                            []
# 38                                            []
# ..                                           ...
# 963                                           []
# 968                                           []
# 986                                           []
# 992                                           []
# 996                                           []
#
#                                             best_offer  \
# 4                                                   {}
# 7                                                   {}
# 22   {"applicable_on":"Orders above Rs. 1499 (only ...
# 32   {"applicable_on":"Orders above Rs. 649 (only o...
# 38   {"applicable_on":"Orders above Rs. 999 (only o...
# ..                                                 ...
# 963  {"applicable_on":"Orders above Rs. 999 (only o...
# 968  {"applicable_on":"Orders above Rs. 999 (only o...
# 986  {"applicable_on":"Orders above Rs. 1299 (only ...
# 992  {"applicable_on":"Orders above Rs. 1499 (only ...
# 996                                                 {}
#
#                                            more_offers   category
# 4    [{"offer_name":"10% Instant Discount on IndusI...  bath-robe
# 7    [{"offer_name":"10% Instant Discount on Citi C...  bedsheets
# 22   [{"offer_name":"10% Instant Discount on IndusI...      boots
# 32   [{"offer_name":"10% Instant Discount on IndusI...        bra
# 38   [{"offer_name":"10% Instant Discount on IndusI...   bracelet
# ..                                                 ...        ...
# 963  [{"offer_name":"10% Instant Discount on IndusI...    tshirts
# 968  [{"offer_name":"10% Instant Discount on IndusI...    tshirts
# 986  [{"offer_name":"10% Instant Discount on Citi C...    watches
# 992  [{"offer_name":"10% Instant Discount on IndusI...    watches
# 996  [{"offer_name":"10% Instant Discount on Citi C...    watches
#
# [104 rows x 24 columns]

# %%
ecommerce_data[(ecommerce_data['discount']>=80) & (ecommerce_data['rating']>=4.6)]
# Out:
#      product_id         title  \
# 628    18690268  Dennis Lingo
# 963    20085320       BULLMER
#
#                                    product_description  rating  ratings_count  \
# 628                 Men Slim Fit Tropical Casual Shirt     4.6              5
# 963  Men Pack of 2 Navy Blue & Turquoise Blue Long ...     4.8             12
#
#      initial_price  discount  final_price currency  \
# 628           1999      80.0  "₹1,999.00"      INR
# 963           3998      80.0    "₹799.00"      INR
#
#                                                 images  ...  \
# 628  http://assets.myntassets.com/assets/images/186...  ...
# 963  http://assets.myntassets.com/assets/images/200...  ...
#
#                                        amount_of_stars what_customers_said  \
# 628  {"1_star":0,"2_stars":0,"3_stars":1,"4_stars":...          No reviews
# 963  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...          No reviews
#
#                   seller_name  \
# 628            Unknown Seller
# 963  Bod███ove███par█████████
#
#                                                  sizes   videos  \
# 628  [{"size":"38","value":"39.0in","value_name":"C...  Unknown
# 963  [{"size":"M","value":"39.0in","value_name":"Ch...  Unknown
#
#                                     seller_information variations  \
# 628                                                 []       [{}]
# 963  Bod███ove███par█████████ No███████████████████...         []
#
#                                             best_offer  \
# 628                                                 {}
# 963  {"applicable_on":"Orders above Rs. 999 (only o...
#
#                                            more_offers category
# 628  [{"offer_name":"10% Instant Discount on Citi C...   shirts
# 963  [{"offer_name":"10% Instant Discount on IndusI...  tshirts
#
# [2 rows x 24 columns]

# %%
ecommerce_data[['title','initial_price','final_price','discount']]
# Out:
#               title  initial_price   final_price  discount
# 0       Lino Perros           3995   "₹3,995.00"      58.0
# 1    Tommy Hilfiger           2899   "₹2,899.00"      35.0
# 2             Lavie           2999   "₹2,999.00"      65.0
# 3            F Gear           1675   "₹1,675.00"      52.0
# 4         MYTRIDENT           2899   "₹2,899.00"      17.0
# ..              ...            ...           ...       ...
# 995           KREDO          11890  "₹11,890.00"      50.0
# 996           GUESS           8900   "₹8,900.00"      45.0
# 997        GIORDANO           7950   "₹7,950.00"      50.0
# 998        Fastrack           3295   "₹2,636.00"      20.0
# 999         BOLDFIT            699     "₹699.00"      31.0
#
# [1000 rows x 4 columns]

# %%
ecommerce_data[['product_id', 'title', 'category', 'rating', 'ratings_count']]
# Out:
#      product_id           title   category  rating  ratings_count
# 0       8376765     Lino Perros  backpacks     3.8             15
# 1       9136281  Tommy Hilfiger  backpacks     4.5             67
# 2      17633752           Lavie  backpacks     4.4            226
# 3       1376949          F Gear  backpacks     4.4           1052
# 4      13939916       MYTRIDENT  bath-robe     4.7             12
# ..          ...             ...        ...     ...            ...
# 995    13698258           KREDO    watches     3.5             11
# 996    16896006           GUESS    watches     5.0             22
# 997     1708108        GIORDANO    watches     2.8              5
# 998    19280114        Fastrack    watches     4.3             17
# 999    18601682         BOLDFIT  yoga-mats     3.8            161
#
# [1000 rows x 5 columns]

# %%
ecommerce_data[['seller_name', 'seller_information', 'best_offer', 'more_offers']]
# Out:
#         seller_name                                 seller_information  \
# 0    Unknown Seller                                                 []
# 1    Unknown Seller                                                 []
# 2    Unknown Seller                                                 []
# 3    Unknown Seller                                                 []
# 4    Unknown Seller                                                 []
# ..              ...                                                ...
# 995  Unknown Seller                                                 []
# 996  Unknown Seller                                                 []
# 997  Unknown Seller                                                 []
# 998  Tru███m R███il  Sho███o. ███-10█████████enu███████████████████...
# 999  Unknown Seller                                                 []
#
#                                             best_offer  \
# 0                                                   {}
# 1                                                   {}
# 2                                                   {}
# 3                                                   {}
# 4                                                   {}
# ..                                                 ...
# 995                                                 {}
# 996                                                 {}
# 997                                                 {}
# 998  {"applicable_on":"Orders above Rs. 1499 (only ...
# 999                                                 {}
#
#                                            more_offers
# 0    [{"offer_name":"10% Instant Discount on Citi C...
# 1    [{"offer_name":"10% Instant Discount on Citi C...
# 2    [{"offer_name":"10% Instant Discount on Citi C...
# 3    [{"offer_name":"10% Instant Discount on Citi C...
# 4    [{"offer_name":"10% Instant Discount on IndusI...
# ..                                                 ...
# 995  [{"offer_name":"10% Instant Discount on Citi C...
# 996  [{"offer_name":"10% Instant Discount on Citi C...
# 997  [{"offer_name":"10% Instant Discount on Citi C...
# 998  [{"offer_name":"10% Instant Discount on IndusI...
# 999  [{"offer_name":"10% Instant Discount on Citi C...
#
# [1000 rows x 4 columns]

# %% [markdown]
# ### 6.Find and Remove the duplicates

# %%
ecommerce_data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # No duplicate data was found in this dataset. If duplicate rows are present, they can be removed using the `drop_duplicates()` function."

# %% [markdown]
# ### 7. Create a derived column (total_amount = price * quantity)

# %%
ecommerce_data.sample()
# Out:
#      product_id   title                             product_description  \
# 105    18962890  Athena  Fuchsia Solid Asymmetric Hem A-Line Maxi Dress
#
#      rating  ratings_count  initial_price  discount final_price currency  \
# 105     4.0             34           2499      64.0   "₹899.00"      INR
#
#                                                 images  ...  \
# 105  http://assets.myntassets.com/assets/images/189...  ...
#
#                                        amount_of_stars  \
# 105  {"1_star":5,"2_stars":2,"3_stars":2,"4_stars":...
#
#                                    what_customers_said    seller_name  \
# 105  [{"percentage":"75","value_name":"Fit, Just Ri...  APE███PPA███S
#
#                                                  sizes   videos  \
# 105  [{"size":"XS","value":"32.5in","value_name":"B...  Unknown
#
#                                     seller_information variations  \
# 105  Plo███o. ███, P█████████2Se███████████████████...       [{}]
#
#                                             best_offer  \
# 105  {"applicable_on":"Orders above Rs. 999 (only o...
#
#                                            more_offers category
# 105  [{"offer_name":"10% Instant Discount on IndusI...  dresses
#
# [1 rows x 24 columns]

# %% [markdown]
# To calculate the total value by multiplying `final_price` and `quantity`, both columns must have numeric data types (`int` or `float`). However, `final_price` is stored as a string, as shown in `ecommerce_data.dtypes`. Therefore, the string values are first cleaned using the `replace()` function and then converted to a numeric type using `astype()`. After the conversion, operations such as multiplication can be performed easily.

# %%
ecommerce_data['final_price'] = ecommerce_data['final_price'].str.replace(r'[₹,"]','',regex=True).astype(float).astype(int)

# %%
ecommerce_data.dtypes
# Out:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                 int64
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# total_amount                int64
# dtype: object

# %%
ecommerce_data['total_amount'] = ecommerce_data['final_price'] * ecommerce_data['ratings_count']

# %%
ecommerce_data.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0         3995      INR
# 1     4.5             67           2899      35.0         2899      INR
# 2     4.4            226           2999      65.0         2999      INR
# 3     4.4           1052           1675      52.0         1675      INR
# 4     4.7             12           2899      17.0         2899      INR
#
#                                               images  ... what_customers_said  \
# 0  http://assets.myntassets.com/assets/images/837...  ...          No reviews
# 1  http://assets.myntassets.com/assets/images/913...  ...          No reviews
# 2  http://assets.myntassets.com/assets/images/176...  ...          No reviews
# 3  http://assets.myntassets.com/assets/images/137...  ...          No reviews
# 4  http://assets.myntassets.com/assets/images/pro...  ...          No reviews
#
#       seller_name                                              sizes  \
# 0  Unknown Seller                               [{"size":"Onesize"}]
# 1  Unknown Seller                               [{"size":"Onesize"}]
# 2  Unknown Seller                                     [{"size":"S"}]
# 3  Unknown Seller                               [{"size":"Onesize"}]
# 4  Unknown Seller  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                 []
# 1                              ["rw-9136281_cae700"]                 []
# 2  ["https://videos.myntassets.com/assets/videos/...                 []
# 3  ["https://videos.myntassets.com/assets/videos/...                 []
# 4                                            Unknown                 []
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                           []         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category total_amount
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks        59925
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks       194233
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks       677774
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks      1762100
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe        34788
#
# [5 rows x 25 columns]

# %%
ecommerce_data.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0         3995      INR
# 1     4.5             67           2899      35.0         2899      INR
# 2     4.4            226           2999      65.0         2999      INR
# 3     4.4           1052           1675      52.0         1675      INR
# 4     4.7             12           2899      17.0         2899      INR
#
#                                               images  ... what_customers_said  \
# 0  http://assets.myntassets.com/assets/images/837...  ...          No reviews
# 1  http://assets.myntassets.com/assets/images/913...  ...          No reviews
# 2  http://assets.myntassets.com/assets/images/176...  ...          No reviews
# 3  http://assets.myntassets.com/assets/images/137...  ...          No reviews
# 4  http://assets.myntassets.com/assets/images/pro...  ...          No reviews
#
#       seller_name                                              sizes  \
# 0  Unknown Seller                               [{"size":"Onesize"}]
# 1  Unknown Seller                               [{"size":"Onesize"}]
# 2  Unknown Seller                                     [{"size":"S"}]
# 3  Unknown Seller                               [{"size":"Onesize"}]
# 4  Unknown Seller  [{"size":"M","value":"45.0in","value_name":"Fr...
#
#                                               videos seller_information  \
# 0                              ["rw-8376765_cae700"]                 []
# 1                              ["rw-9136281_cae700"]                 []
# 2  ["https://videos.myntassets.com/assets/videos/...                 []
# 3  ["https://videos.myntassets.com/assets/videos/...                 []
# 4                                            Unknown                 []
#
#                                     variations best_offer  \
# 0                                         [{}]         {}
# 1                                      [{},{}]         {}
# 2                          [{},{},{},{},{},{}]         {}
# 3                                           []         {}
# 4  [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]         {}
#
#                                          more_offers   category total_amount
# 0  [{"offer_name":"10% Instant Discount on Citi C...  backpacks        59925
# 1  [{"offer_name":"10% Instant Discount on Citi C...  backpacks       194233
# 2  [{"offer_name":"10% Instant Discount on Citi C...  backpacks       677774
# 3  [{"offer_name":"10% Instant Discount on Citi C...  backpacks      1762100
# 4  [{"offer_name":"10% Instant Discount on IndusI...  bath-robe        34788
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 8.Saving the cleaned dataset as a new CSV file.

# %%
ecommerce_data.to_csv('cleaned_ecommerce_data.csv', index=False)
